# %% [markdown]
# <a href="https://colab.research.google.com/github/sharmamalika2000-bot/ML_projects/blob/main/LanguageDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/content/language (1).csv')

# %%
data
# Out:
#                                                     Text  language
# 0      klement gottwaldi surnukeha palsameeriti ning ...  Estonian
# 1      sebes joseph pereira thomas  på eng the jesuit...   Swedish
# 2      ถนนเจริญกรุง อักษรโรมัน thanon charoen krung เ...      Thai
# 3      விசாகப்பட்டினம் தமிழ்ச்சங்கத்தை இந்துப் பத்திர...     Tamil
# 4      de spons behoort tot het geslacht haliclona en...     Dutch
# ...                                                  ...       ...
# 21995  hors du terrain les années  et  sont des année...    French
# 21996  ใน พศ  หลักจากที่เสด็จประพาสแหลมมลายู ชวา อินเ...      Thai
# 21997  con motivo de la celebración del septuagésimoq...   Spanish
# 21998  年月，當時還只有歲的她在美國出道，以mai-k名義推出首張英文《baby i like》，由...   Chinese
# 21999   aprilie sonda spațială messenger a nasa și-a ...  Romanian
#
# [22000 rows x 2 columns]

# %%
data.columns
# Out:
# Index(['Text', 'language'], dtype='object')

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
data
# Out:
#                                                     Text  language
# 0      klement gottwaldi surnukeha palsameeriti ning ...  Estonian
# 1      sebes joseph pereira thomas  på eng the jesuit...   Swedish
# 2      ถนนเจริญกรุง อักษรโรมัน thanon charoen krung เ...      Thai
# 3      விசாகப்பட்டினம் தமிழ்ச்சங்கத்தை இந்துப் பத்திர...     Tamil
# 4      de spons behoort tot het geslacht haliclona en...     Dutch
# ...                                                  ...       ...
# 21995  hors du terrain les années  et  sont des année...    French
# 21996  ใน พศ  หลักจากที่เสด็จประพาสแหลมมลายู ชวา อินเ...      Thai
# 21997  con motivo de la celebración del septuagésimoq...   Spanish
# 21998  年月，當時還只有歲的她在美國出道，以mai-k名義推出首張英文《baby i like》，由...   Chinese
# 21999   aprilie sonda spațială messenger a nasa și-a ...  Romanian
#
# [22000 rows x 2 columns]

# %%
data.isnull().sum()
# Out:
# Text        0
# language    0
# dtype: int64

# %%
data['language'].value_counts()
# Out:
# language
# Estonian      1000
# Swedish       1000
# Thai          1000
# Tamil         1000
# Dutch         1000
# Japanese      1000
# Turkish       1000
# Latin         1000
# Urdu          1000
# Indonesian    1000
# Portugese     1000
# French        1000
# Chinese       1000
# Korean        1000
# Hindi         1000
# Spanish       1000
# Pushto        1000
# Persian       1000
# Romanian      1000
# Russian       1000
# English       1000
# Arabic        1000
# Name: count, dtype: int64

# %%
data.dtypes
# Out:
# Text        object
# language    object
# dtype: object

# %%
x=np.array(data['Text'])
y=np.array(data['language'])

# %%
x
# Out:
# array(['klement gottwaldi surnukeha palsameeriti ning paigutati mausoleumi surnukeha oli aga liiga hilja ja oskamatult palsameeritud ning hakkas ilmutama lagunemise tundemärke  aastal viidi ta surnukeha mausoleumist ära ja kremeeriti zlíni linn kandis aastatel – nime gottwaldov ukrainas harkivi oblastis kandis zmiivi linn aastatel – nime gotvald',
#        'sebes joseph pereira thomas  på eng the jesuits and the sino-russian treaty of nerchinsk  the diary of thomas pereira bibliotheca instituti historici s i --   rome libris ',
#        'ถนนเจริญกรุง อักษรโรมัน thanon charoen krung เริ่มตั้งแต่ถนนสนามไชยถึงแม่น้ำเจ้าพระยาที่ถนนตก กรุงเทพมหานคร เป็นถนนรุ่นแรกที่ใช้เทคนิคการสร้างแบบตะวันตก ปัจจุบันผ่านพื้นที่เขตพระนคร เขตป้อมปราบศัตรูพ่าย เขตสัมพันธวงศ์ เขตบางรัก เขตสาทร และเขตบางคอแหลม',
#        ...,
# ...

# %%
y
# Out:
# array(['Estonian', 'Swedish', 'Thai', ..., 'Spanish', 'Chinese',
#        'Romanian'], dtype=object)

# %%
data
# Out:
#                                                     Text  language
# 0      klement gottwaldi surnukeha palsameeriti ning ...  Estonian
# 1      sebes joseph pereira thomas  på eng the jesuit...   Swedish
# 2      ถนนเจริญกรุง อักษรโรมัน thanon charoen krung เ...      Thai
# 3      விசாகப்பட்டினம் தமிழ்ச்சங்கத்தை இந்துப் பத்திர...     Tamil
# 4      de spons behoort tot het geslacht haliclona en...     Dutch
# ...                                                  ...       ...
# 21995  hors du terrain les années  et  sont des année...    French
# 21996  ใน พศ  หลักจากที่เสด็จประพาสแหลมมลายู ชวา อินเ...      Thai
# 21997  con motivo de la celebración del septuagésimoq...   Spanish
# 21998  年月，當時還只有歲的她在美國出道，以mai-k名義推出首張英文《baby i like》，由...   Chinese
# 21999   aprilie sonda spațială messenger a nasa și-a ...  Romanian
#
# [22000 rows x 2 columns]

# %%
cv= CountVectorizer()

# %%
x=cv.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)

# %%
x_train
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 613529 stored elements and shape (14740, 277720)>

# %%
print(x_train)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 613529 stored elements and shape (14740, 277720)>
#   Coords	Values
#   (0, 197295)	2
#   (0, 197708)	1
#   (0, 197801)	1
#   (0, 198388)	1
#   (0, 197467)	1
#   (0, 197865)	2
#   (0, 197604)	1
#   (0, 198428)	1
#   (0, 198501)	1
#   (0, 198556)	1
#   (0, 197332)	1
#   (0, 197485)	2
#   (0, 198123)	1
#   (0, 197892)	1
#   (0, 197990)	1
#   (0, 198053)	1
#   (0, 198417)	1
#   (0, 197623)	1
#   (1, 197641)	2
#   (1, 197314)	1
#   (1, 197931)	1
#   (1, 197804)	3
#   (1, 198397)	1
#   (1, 197149)	1
#   (1, 197781)	1
#   :	:
#   (14738, 188817)	1
#   (14738, 192004)	1
#   (14738, 157171)	1
#   (14738, 190346)	1
#   (14738, 190725)	1
#   (14738, 189685)	1
#   (14738, 159269)	2
#   (14738, 145431)	1
#   (14738, 173292)	1
#   (14738, 176062)	1
#   (14738, 159959)	1
#   (14738, 190198)	1
#   (14738, 167124)	1
#   (14738, 168158)	1
#   (14738, 180260)	2
#   (14738, 153262)	1
#   (14738, 162150)	1
#   (14738, 153355)	1
# ...

# %%
y_train
# Out:
# array(['Tamil', 'Tamil', 'Arabic', ..., 'Turkish', 'Pushto', 'Japanese'],
#       dtype=object)

# %%
y_test
# Out:
# array(['Japanese', 'Russian', 'Latin', ..., 'Turkish', 'Arabic',
#        'English'], dtype=object)

# %%
model=MultinomialNB()

# %%
model.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
model.score(x_test,y_test)
# Out:
# 0.953168044077135

# %%
user=input('Enter a text')
data=cv.transform([user]).toarray()
output = model.predict(data)
print(output)
